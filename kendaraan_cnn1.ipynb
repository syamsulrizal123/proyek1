# %% [markdown]
# <a href="https://colab.research.google.com/github/syamsulrizal123/proyek1/blob/main/kendaraan_cnn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
ls

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("Kendaraan")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 32x32 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((64, 64))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
print(labels)

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.25, shuffle=True)
print(trainX.shape)
print(testX.shape)
# Out:
# (42, 64, 64, 3)
# (14, 64, 64, 3)

# %%
from keras.layers import Dropout
#MODEL 1
# define our Convolutional Neural Network architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", input_shape=(64, 64, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(16, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.25))
model.add(Dense(100))
model.add(Dense(3))
model.add(Activation("softmax"))

# %%
#MODEL 2
# define our Convolutional Neural Network architecture
model = Sequential()
model.add(Conv2D(16, (3, 3), padding="same", input_shape=(64, 64, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(100))
model.add(Dense(3))
model.add(Activation("softmax"))

# %%
from keras.optimizers import SGD
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY),
	epochs=50, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/50
# 2/2 [==============================] - 0s 144ms/step - loss: 1.1355 - accuracy: 0.2381 - val_loss: 1.0657 - val_accuracy: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0676 - accuracy: 0.4762 - val_loss: 1.0456 - val_accuracy: 0.4286
# Epoch 3/50
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0407 - accuracy: 0.3571 - val_loss: 1.0399 - val_accuracy: 0.4286
# Epoch 4/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9939 - accuracy: 0.4048 - val_loss: 1.0323 - val_accuracy: 0.6429
# Epoch 5/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9732 - accuracy: 0.7857 - val_loss: 1.0322 - val_accuracy: 0.5000
# Epoch 6/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9042 - accuracy: 0.9286 - val_loss: 1.0090 - val_accuracy: 0.5714
# Epoch 7/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8521 - accuracy: 0.9286 - val_loss: 0.9709 - val_accuracy: 0.7143
# Epoch 8/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7826 - accuracy: 0.9524 - val_loss: 0.9170 - val_accuracy: 0.7143
# Epoch 9/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6746 - accuracy: 0.9524 - val_loss: 0.8446 - val_accuracy: 0.7143
# Epoch 10/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5678 - accuracy: 0.9286 - val_loss: 0.7896 - val_accuracy: 0.6429
# Epoch 11/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4857 - accuracy: 0.8810 - val_loss: 0.7436 - val_accuracy: 0.5714
# Epoch 12/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3621 - accuracy: 0.9286 - val_loss: 0.8287 - val_accuracy: 0.7857
# Epoch 13/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3623 - accuracy: 0.9286 - val_loss: 0.7734 - val_accuracy: 0.7143
# Epoch 14/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2301 - accuracy: 0.9762 - val_loss: 0.7268 - val_accuracy: 0.7143
# Epoch 15/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2680 - accuracy: 0.8810 - val_loss: 0.7102 - val_accuracy: 0.7857
# Epoch 16/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1838 - accuracy: 0.9048 - val_loss: 0.8121 - val_accuracy: 0.7143
# Epoch 17/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1401 - accuracy: 0.9762 - val_loss: 1.2659 - val_accuracy: 0.5000
# Epoch 18/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2498 - accuracy: 0.9048 - val_loss: 0.9833 - val_accuracy: 0.7143
# Epoch 19/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.8254 - val_accuracy: 0.7857
# Epoch 20/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1261 - accuracy: 0.9524 - val_loss: 0.9539 - val_accuracy: 0.7857
# Epoch 21/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1964 - accuracy: 0.9048 - val_loss: 0.8697 - val_accuracy: 0.6429
# Epoch 22/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0855 - accuracy: 0.9762 - val_loss: 1.0335 - val_accuracy: 0.7143
# Epoch 23/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 1.3730 - val_accuracy: 0.7143
# Epoch 24/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0916 - accuracy: 0.9762 - val_loss: 1.3095 - val_accuracy: 0.7143
# Epoch 25/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 1.0525 - val_accuracy: 0.6429
# Epoch 26/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 1.0952 - val_accuracy: 0.7143
# Epoch 27/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 1.1581 - val_accuracy: 0.6429
# Epoch 28/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0387 - accuracy: 0.9762 - val_loss: 1.2210 - val_accuracy: 0.6429
# Epoch 29/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.4052 - val_accuracy: 0.6429
# Epoch 30/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.6104 - val_accuracy: 0.6429
# Epoch 31/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.7253 - val_accuracy: 0.6429
# Epoch 32/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.6614 - val_accuracy: 0.6429
# Epoch 33/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.5630 - val_accuracy: 0.7143
# Epoch 34/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.4745 - val_accuracy: 0.7143
# Epoch 35/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.4149 - val_accuracy: 0.6429
# Epoch 36/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.3850 - val_accuracy: 0.6429
# Epoch 37/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3798 - val_accuracy: 0.6429
# Epoch 38/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3925 - val_accuracy: 0.6429
# Epoch 39/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.4259 - val_accuracy: 0.6429
# Epoch 40/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.4946 - val_accuracy: 0.6429
# Epoch 41/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.5688 - val_accuracy: 0.6429
# Epoch 42/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.6358 - val_accuracy: 0.6429
# Epoch 43/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.6818 - val_accuracy: 0.6429
# Epoch 44/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.7110 - val_accuracy: 0.6429
# Epoch 45/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.7242 - val_accuracy: 0.6429
# Epoch 46/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.7201 - val_accuracy: 0.6429
# Epoch 47/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.7096 - val_accuracy: 0.6429
# Epoch 48/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.7004 - val_accuracy: 0.6429
# Epoch 49/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.6965 - val_accuracy: 0.6429
# Epoch 50/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.6952 - val_accuracy: 0.6429

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#        Mobil       0.60      0.60      0.60         5
#        Motor       0.67      0.67      0.67         3
#      Pesawat       0.67      0.67      0.67         6
#
#     accuracy                           0.64        14
#    macro avg       0.64      0.64      0.64        14
# weighted avg       0.64      0.64      0.64        14

# %%
index=5

image = np.expand_dims(testX[index], axis=0)
output = model.predict(image, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# [[9.8294365e-01 1.6692821e-02 3.6359811e-04]]
# ['Mobil']

# %%
imageY=testY[index]
print(imageY)
# Out:
# [1 0 0]

# %%
result = np.where(imageY == np.amax(imageY))
# print('Returned tuple of arrays :', result)
# print('List of Indices of maximum element :', result[0])
print(lb.classes_[result])
# Out:
# ['Mobil']

# %%
import cv2
import matplotlib.pyplot as plt
image1='motor_test1.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()
# print(type(img_array))

# %%
image_testing = Image.open('5.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# [[2.4232568e-04 9.9975759e-01 9.0005372e-08]]
# ['Motor']
